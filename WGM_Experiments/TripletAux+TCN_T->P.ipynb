# %%
# %load_ext autoreload
# %autoreload complete

# %%
import numpy as np
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import data_accessor as acc
datas = [
    'temperature_230509_discrete',
    'pressure_230516_discrete'
    ]
data_dictionary = acc.setup(datas)
# Out:
# loading temperature_230509_discrete__________________________
# 	input shape (number, dimension): (6000, 10000)
# 	label shape (number, dimension): (6000, 1)
# 	there are 16 folds
# 	4200 for training, 600 for validating, 1200 for testing
# loading pressure_230516_discrete__________________________
# 	input shape (number, dimension): (5000, 10000)
# 	label shape (number, dimension): (5000, 1)
# 	there are 16 folds
# 	3500 for training, 500 for validating, 1000 for testing

# %%
from CrossValidation import CrossValidator
from tools import SaveBestCrossValidationModel
from Triplet_TCN import TripletAux_and_TCNDataset, TripletAux_and_TCNManager
from data import alternate_rows_itertools
s = {
    'problem'           : "regression",
    'approach'          : "metric learning/non-parametric",
    'algorithm'         : "triplet network",
    'input'             : "samples from a distribution",
    'input type'        : "vectors",
    'input meaning'     : "spectrum", 
    'input dimension'   : 10000,
    'input channels'    : 1,
    'output'            : "samples from a distribution",
    'output type'       : "one number",
    'output meaning'    : "temperature or pressure, depending on distribution",
    'output dimension'  : 1,
    'learning rate'     : 1e-4, # was 1e-4
    'feature dimension' : 300,
    'cross validation round': 16,
    'cross validation round-development' : 2,
    'epoch'             : 1000,
    'epoch-development' : 20,
    'batch size'        : 64,
    'number of convolution levels': 3,
    'best model folder' : 'triplet_best_model/'
}
# datas.reverse()
CVtor = CrossValidator(saver=SaveBestCrossValidationModel(s['best model folder']), 
                       dataset=TripletAux_and_TCNDataset,
                       datas=datas,
                       data_dictionary=data_dictionary,
                       manager=TripletAux_and_TCNManager,
                       settings=s,
                       device=device,
                       dev=False)
# CVtor.single_task_train(1)
CVtor.multi_task_train_sequential()
# CVtor.multi_task_train_weave(alternate_rows_itertools) 
CVtor.complete_notify()
CVtor.test_all()
# Out:
# __________CROSS VALIDATION__________
# Cross-validation rounds: 16
# Epochs: 1000
# Datas to learn:
# 	0: temperature_230509_discrete
# 	1: pressure_230516_discrete
# MULTI TASK, Sequential____________________________
# we're learning: multiple tasks
# given [1, 2, 3], [a, b, c]: learn [1, 2, 3], reset model, learn [a, b, c]
# CV round 0_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 25
# min train loss: 0.00012077937549981994
# min valid loss: 0.0001062502502463758
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 32
# min train loss: 0.00010730760074114766
# min valid loss: 0.00010164433388126781
# CV round 1_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 17
# min train loss: 0.00011910499421047103
# min valid loss: 9.888894710456953e-05
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 39
# min train loss: 7.871583564503287e-05
# min valid loss: 7.10324379724625e-05
# CV round 2_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 16
# min train loss: 0.00010382321113755813
# min valid loss: 0.00015411292624776252
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 23
# min train loss: 0.00013941459394779733
# min valid loss: 0.0001281485747313127
# CV round 3_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 15
# min train loss: 0.00012686452927565287
# min valid loss: 0.00016751910516177304
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 22
# min train loss: 0.00013011537018676542
# min valid loss: 0.0001345010368822841
# CV round 4_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 19
# min train loss: 0.0001250921929816038
# min valid loss: 8.435691852355376e-05
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 25
# min train loss: 0.00011832622364057567
# min valid loss: 0.00013848278103978373
# CV round 5_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 28
# min train loss: 0.0001049908070964386
# min valid loss: 0.00010862247509066947
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 21
# min train loss: 0.00013132219411834904
# min valid loss: 0.0001415087899658829
# CV round 6_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 25
# min train loss: 9.777812771393324e-05
# min valid loss: 9.512672768323683e-05
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 36
# min train loss: 8.488691614316353e-05
# min valid loss: 7.874318043832318e-05
# CV round 7_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 21
# min train loss: 0.00010984357361325458
# min valid loss: 0.00015920624064165169
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 38
# min train loss: 9.713987826464952e-05
# min valid loss: 9.857679469860159e-05
# CV round 8_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 20
# min train loss: 0.00010633315788723077
# min valid loss: 9.805367117223795e-05
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 41
# min train loss: 0.0001255198634515347
# min valid loss: 0.00010328283860872034
# CV round 9_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 17
# min train loss: 0.00010152582526092318
# min valid loss: 0.0001390316196193453
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 30
# min train loss: 0.0001044890080017715
# min valid loss: 9.123784275288926e-05
# CV round 10_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 23
# min train loss: 0.0001319872655144674
# min valid loss: 0.00012178587348898873
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 18
# min train loss: 0.00022327376910569993
# min valid loss: 0.00022251702284847852
# CV round 11_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 20
# min train loss: 9.473322819703202e-05
# min valid loss: 0.0001697148683888372
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 39
# min train loss: 9.66393684476233e-05
# min valid loss: 8.469871863781009e-05
# CV round 12_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 24
# min train loss: 9.480601891647728e-05
# min valid loss: 0.00011998966947430744
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 35
# min train loss: 0.00011924686669689519
# min valid loss: 0.00013266297628433676
# CV round 13_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 22
# min train loss: 0.00010525175992260108
# min valid loss: 0.00010277342953486368
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 25
# min train loss: 0.00012437951478535647
# min valid loss: 0.0001355209651592304
# CV round 14_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 17
# min train loss: 0.00014577134612464403
# min valid loss: 0.00011794679376180284
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 42
# min train loss: 0.00011177732277164151
# min valid loss: 0.00011424215699662454
# CV round 15_________________________________
# using: 0 temperature_230509_discrete
# EARLY STOPPING @ epoch 23
# min train loss: 0.00010481720136974191
# min valid loss: 0.0001203993997478392
# using: 1 pressure_230516_discrete
# EARLY STOPPING @ epoch 27
# min train loss: 0.00011916481942700391
# min valid loss: 7.806814664945705e-05
# BEST model: CV=1.pth with 7.10324379724625e-05
# trained datas sequentially
# Aggregate performance:
# temperature_230509_discrete: Valid loss mean 0.0001227361822429884, std 2.6353510053503e-05
# pressure_230516_discrete: Valid loss mean 0.00011592928734671659, std 3.6026857061894264e-05
# 😇 TRAINing COMPLETE____________________________
# TEST____________________________
# Testing temperature_230509_discrete, loss:  0.3051403980506094
# Testing pressure_230516_discrete, loss:  0.0001125039689213736
