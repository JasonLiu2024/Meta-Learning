# %%
# %load_ext autoreload
# %autoreload complete

# %%
import numpy as np
import torch
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
import data_accessor as acc
datas = [
    'temperature_230509_discrete',
    'pressure_230516_discrete'
    ]
data_dictionary = acc.setup(datas)
# Out:
# loading temperature_230509_discrete__________________________
# 	input shape (number, dimension): (6000, 10000)
# 	label shape (number, dimension): (6000, 1)
# 	there are 16 folds
# 	4200 for training, 600 for validating, 1200 for testing
# loading pressure_230516_discrete__________________________
# 	input shape (number, dimension): (5000, 10000)
# 	label shape (number, dimension): (5000, 1)
# 	there are 16 folds
# 	3500 for training, 500 for validating, 1000 for testing

# %%
from CrossValidation import CrossValidator
from tools import SaveBestCrossValidationModel
from Triplet_TCN import TripletAux_and_TCNDataset, TripletAux_and_TCNManager
from data import alternate_rows_itertools
s = {
    'problem'           : "regression",
    'approach'          : "metric learning/non-parametric",
    'algorithm'         : "triplet network",
    'input'             : "samples from a distribution",
    'input type'        : "vectors",
    'input meaning'     : "spectrum", 
    'input dimension'   : 10000,
    'input channels'    : 1,
    'output'            : "samples from a distribution",
    'output type'       : "one number",
    'output meaning'    : "temperature or pressure, depending on distribution",
    'output dimension'  : 1,
    'learning rate'     : 1e-4, # was 1e-4
    'feature dimension' : 300,
    'cross validation round': 16,
    'cross validation round-development' : 2,
    'epoch'             : 1000,
    'epoch-development' : 20,
    'batch size'        : 64,
    'number of convolution levels': 3,
    'best model folder' : 'triplet_best_model/'
}
datas.reverse()
CVtor = CrossValidator(saver=SaveBestCrossValidationModel(s['best model folder']), 
                       dataset=TripletAux_and_TCNDataset,
                       datas=datas,
                       data_dictionary=data_dictionary,
                       manager=TripletAux_and_TCNManager,
                       settings=s,
                       device=device,
                       dev=False)
# CVtor.single_task_train(1)
CVtor.multi_task_train_sequential()
# CVtor.multi_task_train_weave(alternate_rows_itertools) 
CVtor.complete_notify()
CVtor.test_all()
# Out:
# __________CROSS VALIDATION__________
# Cross-validation rounds: 16
# Epochs: 1000
# Datas to learn:
# 	0: pressure_230516_discrete
# 	1: temperature_230509_discrete
# MULTI TASK, Sequential____________________________
# we're learning: multiple tasks
# given [1, 2, 3], [a, b, c]: learn [1, 2, 3], reset model, learn [a, b, c]
# CV round 0_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 37
# min train loss: 9.059750915515575e-05
# min valid loss: 8.224435441661626e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 15
# min train loss: 0.00012352742774193317
# min valid loss: 0.0001229079563927371
# CV round 1_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 38
# min train loss: 8.169602178068916e-05
# min valid loss: 7.05956481397152e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 19
# min train loss: 0.00011489568896649871
# min valid loss: 9.763282068888656e-05
# CV round 2_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 25
# min train loss: 0.00011878813926490362
# min valid loss: 0.00015039698428154225
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 20
# min train loss: 0.0001116892638520133
# min valid loss: 0.00015138090238906444
# CV round 3_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 36
# min train loss: 8.984570482756349e-05
# min valid loss: 8.725534280529246e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 22
# min train loss: 0.00011177193195952427
# min valid loss: 0.00015952670364640653
# CV round 4_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 35
# min train loss: 8.283379191363399e-05
# min valid loss: 7.551946328021586e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 17
# min train loss: 0.00010752741515964523
# min valid loss: 8.080435000010767e-05
# CV round 5_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 34
# min train loss: 8.913559550736946e-05
# min valid loss: 7.684532101848163e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 27
# min train loss: 0.00010569208825472742
# min valid loss: 8.453109185211361e-05
# CV round 6_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 29
# min train loss: 8.425856378215196e-05
# min valid loss: 8.125362273858627e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 23
# min train loss: 0.00010671018186037668
# min valid loss: 0.00011673877088469453
# CV round 7_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 27
# min train loss: 0.00011330502748023719
# min valid loss: 0.0001211537510243943
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 23
# min train loss: 7.889425184905782e-05
# min valid loss: 0.00014238379771995823
# CV round 8_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 31
# min train loss: 9.815398595740342e-05
# min valid loss: 9.65866547630867e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 29
# min train loss: 9.623963077584366e-05
# min valid loss: 8.220187592087314e-05
# CV round 9_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 34
# min train loss: 0.00012755956466373227
# min valid loss: 9.589393903297605e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 15
# min train loss: 0.00011598425071772935
# min valid loss: 0.00016523397207492962
# CV round 10_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 42
# min train loss: 7.37153824461116e-05
# min valid loss: 7.604763050039764e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 24
# min train loss: 9.664445210408744e-05
# min valid loss: 0.00011259511484240647
# CV round 11_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 42
# min train loss: 7.777793209904551e-05
# min valid loss: 6.821464603490313e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 35
# min train loss: 7.636429202675848e-05
# min valid loss: 0.0001369391342450399
# CV round 12_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 35
# min train loss: 7.493210154776039e-05
# min valid loss: 8.263990366685903e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 15
# min train loss: 0.00011082182887052609
# min valid loss: 0.00014557898393832147
# CV round 13_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 29
# min train loss: 9.56071431573946e-05
# min valid loss: 0.00010026042673416669
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 19
# min train loss: 0.00012767422584037183
# min valid loss: 0.00011714638458215632
# CV round 14_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 44
# min train loss: 7.091095480559902e-05
# min valid loss: 6.211605796124786e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 29
# min train loss: 0.00011107036940908681
# min valid loss: 9.379025577800348e-05
# CV round 15_________________________________
# using: 0 pressure_230516_discrete
# EARLY STOPPING @ epoch 33
# min train loss: 0.00010338893692030317
# min valid loss: 9.800770021684002e-05
# using: 1 temperature_230509_discrete
# EARLY STOPPING @ epoch 17
# min train loss: 9.627654633897527e-05
# min valid loss: 0.00010212759443675167
# BEST model: CV=4.pth with 8.080435000010767e-05
# trained datas sequentially
# Aggregate performance:
# pressure_230516_discrete: Valid loss mean 8.906446541345758e-05, std 2.129593368749522e-05
# temperature_230509_discrete: Valid loss mean 0.00011946998183702816, std 2.7206116164630253e-05
# 😇 TRAINing COMPLETE____________________________
# TEST____________________________
# Testing pressure_230516_discrete, loss:  4.034363076090813
# Testing temperature_230509_discrete, loss:  0.0001221206085143709
